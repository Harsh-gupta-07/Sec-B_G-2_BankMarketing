# %% [markdown]
# # 01 Extraction
#
# Load the raw bank marketing dataset, confirm the file structure, and cross-check the source columns against [`docs/data_dictionary.md`](../docs/data_dictionary.md).

# %%
from pathlib import Path

import pandas as pd
from IPython.display import display

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().resolve().name == 'notebooks' else Path.cwd().resolve()
RAW_PATH = PROJECT_ROOT / 'data/raw/bank-full.csv'
DICTIONARY_PATH = PROJECT_ROOT / 'docs/data_dictionary.md'

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 120)
pd.set_option('display.max_colwidth', 80)

# %%
raw_df = pd.read_csv(RAW_PATH, sep=';')
raw_df.head()
# Out:
#    age           job  marital  education default  balance housing loan  contact  day month  duration  campaign  pdays  \
# 0   58    management  married   tertiary      no     2143     yes   no  unknown    5   may       261         1     -1
# 1   44    technician   single  secondary      no       29     yes   no  unknown    5   may       151         1     -1
# 2   33  entrepreneur  married  secondary      no        2     yes  yes  unknown    5   may        76         1     -1
# 3   47   blue-collar  married    unknown      no     1506     yes   no  unknown    5   may        92         1     -1
# 4   33       unknown   single    unknown      no        1      no   no  unknown    5   may       198         1     -1
#
#    previous poutcome   y
# 0         0  unknown  no
# 1         0  unknown  no
# 2         0  unknown  no
# 3         0  unknown  no
# 4         0  unknown  no

# %%
print(f'Raw path: {RAW_PATH}')
print(f'Rows: {len(raw_df):,}')
print(f'Columns: {len(raw_df.columns):,}')
print(f'Duplicates: {raw_df.duplicated().sum():,}')
print(f'Total missing values: {int(raw_df.isna().sum().sum()):,}')

display(raw_df.info())
display(raw_df['y'].value_counts(dropna=False).rename_axis('target').to_frame('count'))
# Out:
# Raw path: /Users/Harsh/Documents/Github/Sec-B_G-2_BankMarketing/data/raw/bank-full.csv
# Rows: 45,211
# Columns: 17
# Duplicates: 0
# Total missing values: 0
# <class 'pandas.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  str
#  2   marital    45211 non-null  str
#  3   education  45211 non-null  str
#  4   default    45211 non-null  str
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  str
#  7   loan       45211 non-null  str
#  8   contact    45211 non-null  str
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  str
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  str
# ...

# %%
column_reference = pd.DataFrame(
    [
        ('age', 'integer', 'Client age in years', '58', 'EDA, statistical analysis, Tableau'),
        ('job', 'string', 'Occupation category', 'management', 'EDA, segmentation, Tableau'),
        ('marital', 'string', 'Marital status', 'married', 'EDA, segmentation, Tableau'),
        ('education', 'string', 'Education level', 'tertiary', 'EDA, segmentation, Tableau'),
        ('default', 'string', 'Whether the client has credit in default', 'no', 'EDA, segmentation, Tableau'),
        ('balance', 'integer', 'Average yearly balance in euros', '2143', 'EDA, statistical analysis, Tableau'),
        ('housing', 'string', 'Whether the client has a housing loan', 'yes', 'EDA, segmentation, Tableau'),
        ('loan', 'string', 'Whether the client has a personal loan', 'no', 'EDA, segmentation, Tableau'),
        ('contact', 'string', 'Contact communication type', 'unknown', 'EDA, segmentation, Tableau'),
        ('day', 'integer', 'Day of the month of the last contact', '5', 'EDA, Tableau'),
        ('month', 'string', 'Month of the last contact', 'may', 'EDA, statistical analysis, Tableau'),
        ('duration', 'integer', 'Last contact duration in seconds', '261', 'EDA, statistical analysis'),
        ('campaign', 'integer', 'Number of contacts in this campaign for the client', '1', 'EDA, statistical analysis, Tableau'),
        ('pdays', 'integer', 'Days since the client was last contacted', '-1', 'EDA, statistical analysis, Tableau'),
        ('previous', 'integer', 'Number of contacts before this campaign', '0', 'EDA, statistical analysis, Tableau'),
        ('poutcome', 'string', 'Outcome of the previous campaign', 'unknown', 'EDA, statistical analysis, Tableau'),
        ('y', 'string', 'Target flag: subscribed to a term deposit', 'no', 'All notebooks'),
    ],
    columns=['Column Name', 'Data Type', 'Description', 'Example Value', 'Used In'],
)

display(column_reference)
display(raw_df.describe(include='all').T)
# Out:
#    Column Name Data Type                                         Description Example Value  \
# 0          age   integer                                 Client age in years            58
# 1          job    string                                 Occupation category    management
# 2      marital    string                                      Marital status       married
# 3    education    string                                     Education level      tertiary
# 4      default    string            Whether the client has credit in default            no
# 5      balance   integer                     Average yearly balance in euros          2143
# 6      housing    string               Whether the client has a housing loan           yes
# 7         loan    string              Whether the client has a personal loan            no
# 8      contact    string                          Contact communication type       unknown
# ...
